# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("nas.csv")

# %%
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.dtypes
# Out:
# STUID                  int64
# State                 object
# District               int64
# Gender                object
# Age                   object
#                       ...
# Help.in.household     object
# Maths..              float64
# Reading..            float64
# Science..            float64
# Social..             float64
# Length: 64, dtype: object

# %%
df.isnull().sum()
# Out:
# STUID                   0
# State                   0
# District                0
# Gender                  2
# Age                   232
#                      ...
# Help.in.household      44
# Maths..              4611
# Reading..            4574
# Science..            4657
# Social..             4682
# Length: 64, dtype: int64

# %%
df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
df.Siblings.value_counts()
# Out:
# Siblings
# 2 siblings      2979
# 1 sibling       2726
# 3 siblings      1526
# 4+ siblings     1167
# Single child     403
# Name: count, dtype: int64

# %%
df["Mother.edu"].value_counts()
# Out:
# Mother.edu
# Secondary         2591
# Illiterate        2545
# Primary           2220
# Sr secondary       433
# Degree & above     161
# Name: count, dtype: int64

# %%
contingency_table = pd.crosstab(df['Siblings'], df['Mother.edu'])

# %%
contingency_table
# Out:
# Mother.edu    Degree & above  Illiterate  Primary  Secondary  Sr secondary
# Siblings
# 1 sibling                 88         533      689       1050           206
# 2 siblings                36         923      771        846           132
# 3 siblings                11         532      417        348            48
# 4+ siblings                6         469      251        255            23
# Single child              20          88       92         92            24

# %%
sns.heatmap(contingency_table, annot=True, cmap='Blues')
plt.title('Heatmap')
plt.ylabel('Siblings')
plt.xlabel('Mother Education')
plt.show()

# %%
df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
df.Age
# Out:
# 0       13 years
# 1       15 years
# 2       14 years
# 3       13 years
# 4       14 years
#           ...
# 8796    13 years
# 8797    13 years
# 8798    14 years
# 8799    13 years
# 8800    13 years
# Name: Age, Length: 8801, dtype: object

# %%
df.Age.isnull().sum()
# Out:
# 232

# %%
df.Age.fillna("0")
# Out:
# 0       13 years
# 1       15 years
# 2       14 years
# 3       13 years
# 4       14 years
#           ...
# 8796    13 years
# 8797    13 years
# 8798    14 years
# 8799    13 years
# 8800    13 years
# Name: Age, Length: 8801, dtype: object

# %%
df.Age = df.Age.apply(lambda x: float(x.replace(" years", "").replace("+", "").replace("-", ""))  if type(x) == str else x)

# %%
df.Age
# Out:
# 0       13.0
# 1       15.0
# 2       14.0
# 3       13.0
# 4       14.0
#         ...
# 8796    13.0
# 8797    13.0
# 8798    14.0
# 8799    13.0
# 8800    13.0
# Name: Age, Length: 8801, dtype: float64

# %%
df1 = df[df.Age > 11]

# %%
pivot_table = df.pivot(columns=['Age','Father.edu'], values='Science..')

# %%
plt.figure(figsize=(50,60))
sns.heatmap(pivot_table, annot=True, fmt="g", cmap='Blues', cbar_kws={'label': 'Science..'})
plt.title('Heatmap of Values by Category1 and Category2')
plt.xlabel('Category2')
plt.ylabel('Category1')
# Out:
# Text(595.7222222222223, 0.5, 'Category1')

# %%
age = df.Age.str.contains("11")
df[age]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 age = df.Age.str.contains("11")
# ----> 2 df[age]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     132         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
df_filtered = df[df['Age'] != 11]

# Create a pivot table for the heatmap
pivot_table = df_filtered.pivot_table(index='Age', columns='Father.edu', values='Science..', aggfunc='mean')

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='viridis', cbar_kws={'label': 'Average Science Marks'})
plt.title('Heatmap of Average Science Marks by Age and Father\'s Education Level')
plt.xlabel('Father\'s Education Level')
plt.ylabel('Age')
plt.show()
