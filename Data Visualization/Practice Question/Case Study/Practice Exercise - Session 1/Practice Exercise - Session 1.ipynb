# %%
#Import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### I - Virat Kohli Dataset

# %%
df = pd.read_csv("virat.csv")

# %%
df.head()
# Out:
#   Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0   12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1   37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2   25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3   54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4   31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date
# 0       Dambulla  18-Aug-08
# 1       Dambulla  20-Aug-08
# 2  Colombo (RPS)  24-Aug-08
# 3  Colombo (RPS)  27-Aug-08
# 4  Colombo (RPS)  29-Aug-08

# %%
def isOut(runs):
    return False if '*' in runs else True

# %%
df["Out"] = df["Runs"].apply(isOut)

# %%
df[df.Out == False]
# Out:
#      Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns      Opposition  \
# 5      2*    6    2   0   0     100    7   not out     1     v Sri Lanka
# 12   102*  128   95  11   0  107.36    3   not out     2    v Bangladesh
# 24    63*   83   70   6   2      90    3   not out     2   v New Zealand
# 30    87*  126   92   7   2   94.56    3   not out     2  v South Africa
# 32   100*  113   83   8   2  120.48    4   not out     1    v Bangladesh
# 49   112*  134   98  16   0  114.28    4   not out     2       v England
# 51    86*    -   99  11   0   86.86    4   not out     2       v England
# 56    23*   15   11   3   0  209.09    6   not out     1   v West Indies
# 66   128*  187  119  12   1  107.56    3   not out     2     v Sri Lanka
# 73    77*  110   79   9   2   97.46    3   not out     2       v England
# 81    68*  128   88   5   1   77.27    3   not out     2      v Zimbabwe
# 83   100*   82   52   8   7   192.3    3   not out     2     v Australia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        132 non-null    object
#  1   Mins        132 non-null    object
#  2   BF          132 non-null    int64
#  3   4s          132 non-null    int64
#  4   6s          132 non-null    int64
#  5   SR          132 non-null    object
#  6   Pos         132 non-null    int64
#  7   Dismissal   132 non-null    object
#  8   Inns        132 non-null    int64
#  9   Opposition  132 non-null    object
#  10  Ground      132 non-null    object
#  11  Start Date  132 non-null    object
#  12  Out         132 non-null    bool
# dtypes: bool(1), int64(5), object(7)
# memory usage: 12.6+ KB

# %% [markdown]
# #### Spread in Runs
# Question 1: Analyse the spread of Runs scored by Virat in all his matches and report the difference between the scores at the 50th percentile and the 25th percentile respectively.
#
#     a)16.5
#     b)22.5
#     c)26.5
#     d)32.5

# %%
## Your code here
df.Runs = df.Runs.apply(lambda x: int(x[:-1]) if "*" in x else int(x))

# %%
df.Runs.dtypes
# Out:
# dtype('int64')

# %%
plt.boxplot(df.Runs)
plt.show()

# %%
df.Runs.describe()
# Out:
# count    132.000000
# mean      46.848485
# std       41.994635
# min        0.000000
# 25%       10.000000
# 50%       32.500000
# 75%       80.250000
# max      154.000000
# Name: Runs, dtype: float64

# %% [markdown]
# #### Box Plots
#
# Question 2: Plot a Box Plot to analyse the spread of Runs that Virat has scored. The upper fence in the box plot lies in which interval?
#
#     a)100-120
#     b)120-140
#     c)140-160
#     d)160-180

# %%
#Your code here

# %% [markdown]
# #### False Statement
#
# Q3:Consider the following statements and choose the correct option
#
#      I - Virat has played the maximum number of matches in 2011
#      II - Virat has the highest run average in the year 2017
#      III - Virat has the maximum score in a single match and the highest run average in the year 2016.
#
# Which of the above statements is/are false?
#
#     a)I and II
#     b)I and III
#     c)II
#     d)III

# %%
## Your code here
import re

def getYear(date):
    # Extracting year using regular expression
    year_match = re.search(r'\d{2}$', date)

    if year_match:
        year = int(year_match.group())
        # Assuming a range for the year, e.g., 2000-2099
        if year <= 21:
            year += 2000
        else:
            year += 1900
        return year

# %%
df["Year"] = df["Start Date"].apply(getYear)

# %%
df.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date   Out  Year
# 0       Dambulla  18-Aug-08  True  2008
# 1       Dambulla  20-Aug-08  True  2008
# 2  Colombo (RPS)  24-Aug-08  True  2008
# 3  Colombo (RPS)  27-Aug-08  True  2008
# 4  Colombo (RPS)  29-Aug-08  True  2008

# %%
plt.hist(df.Year, bins=20)
plt.show()

# %%
df.Runs.describe()
# Out:
# count    132.000000
# mean      46.848485
# std       41.994635
# min        0.000000
# 25%       10.000000
# 50%       32.500000
# 75%       80.250000
# max      154.000000
# Name: Runs, dtype: float64

# %%
df[df.Runs == 154]
# Out:
#      Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 126   154  202  134  16   1  114.92    3   not out     2  v New Zealand
#
#      Ground Start Date    Out  Year
# 126  Mohali  23-Oct-16  False  2016

# %%
df.Year.value_counts()
# Out:
# Year
# 2011    31
# 2013    23
# 2014    17
# 2010    16
# 2012    11
# 2015    10
# 2016    10
# 2009     6
# 2008     5
# 2017     3
# Name: count, dtype: int64

# %%
pivot_table = df.pivot_table(
    index=None, 
    columns='Year', 
    values='Runs', 
    aggfunc=[np.mean, np.max]
)
pivot_table
# Out:
#       mean                                                                  \
# Year  2008       2009    2010  2011       2012       2013       2014  2015
# Runs  31.8  38.333333  45.375  42.0  40.363636  47.826087  58.529412  30.4
#
#                       amax
# Year  2016       2017 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
# Runs  73.9  61.666667   54  107  118  117  128  115  139  138  154  122

# %%
pd.pivot_table(df, values='Runs',columns=['Year'], aggfunc=np.mean)
# Out:
# Year  2008       2009    2010  2011       2012       2013       2014  2015  \
# Runs  31.8  38.333333  45.375  42.0  40.363636  47.826087  58.529412  30.4
#
# Year  2016       2017
# Runs  73.9  61.666667

# %%
pd.pivot_table(df, values='Runs',columns=['Year'], aggfunc=np.max)
# Out:
# Year  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# Runs    54   107   118   117   128   115   139   138   154   122

# %% [markdown]
# #### Maximum Frequency
#
# Q4:Plot a histogram for the Mins column with 15 bins. Among the three ranges mentioned below, which one has the highest frequency?
#
# A - [54.6,68)
#
# B - [68,81.4)
#
# C - [121.6,135)
#
# D - [1, 14.4)
#
#     a)A - [54.6,68)
#     b)B - [68,81.4)
#     c)C - [121.6,135)
#     d)D - [1, 14.4)

# %%
#Your code here
df.Mins = df.Mins.apply(lambda x: int(x) if x.isdigit() else 0)

# %%
plt.figure(figsize=(20, 6))
plt.hist(df.Mins, bins = 15)
plt.xticks(rotation=90)
plt.show()
