# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Create a DF cars using raw stored data in dictionary

# %%
cars_per_cap = [900,700,600,250,350,100,50] 
country = ['united States','Australia','Japan','India','Russia','Morocco','Egypt'] 
drive_right = [True,False,False,False,True,True,True]

# %%
data = {"cars_per_cap": cars_per_cap,"country": country, "drive_right": drive_right}

# %%
data
# Out:
# {'cars_per_cap': [900, 700, 600, 250, 350, 100, 50],
#  'country': ['united States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drive_right': [True, False, False, False, True, True, True]}

# %%
cars = pd.DataFrame(data)
cars
# Out:
#    cars_per_cap        country  drive_right
# 0           900  united States         True
# 1           700      Australia        False
# 2           600          Japan        False
# 3           250          India        False
# 4           350         Russia         True
# 5           100        Morocco         True
# 6            50          Egypt         True

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars_df = pd.read_csv(r"D:\Upgrad\Dataset\cars.csv", header=None)
cars_df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
cars_df.columns
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
cars_df.columns = ["country code", "region","country","cars_per_caps","drive_right"]

# %%
cars_df
# Out:
#   country code region        country  cars_per_caps  drive_right
# 0         USCA     US  United States          809.0        False
# 1        ASPAC    AUS      Australia          731.0         True
# 2        ASPAC    JAP          Japan          588.0         True
# 3        ASPAC     IN          India           18.0         True
# 4        ASPAC     RU         Russia          200.0        False
# 5        LATAM    MOR        Morocco           70.0        False
# 6          AFR     EG          Egypt           45.0        False
# 7          EUR    ENG        England            NaN         True

# %%
import numpy as np 
import pandas as pd 
cars_df = pd.read_csv(r'D:\Upgrad\Dataset\cars.csv', header=None, index_col=0) 
cars_df.columns = ["region","country","cars_per_caps","drive_right"] 
cars_df
# Out:
#       region        country  cars_per_caps  drive_right
# 0
# USCA      US  United States          809.0        False
# ASPAC    AUS      Australia          731.0         True
# ASPAC    JAP          Japan          588.0         True
# ASPAC     IN          India           18.0         True
# ASPAC     RU         Russia          200.0        False
# LATAM    MOR        Morocco           70.0        False
# AFR       EG          Egypt           45.0        False
# EUR      ENG        England            NaN         True

# %%
cars_df.index.name = "country code"
cars_df
# Out:
#              region        country  cars_per_caps  drive_right
# country code
# USCA             US  United States          809.0        False
# ASPAC           AUS      Australia          731.0         True
# ASPAC           JAP          Japan          588.0         True
# ASPAC            IN          India           18.0         True
# ASPAC            RU         Russia          200.0        False
# LATAM           MOR        Morocco           70.0        False
# AFR              EG          Egypt           45.0        False
# EUR             ENG        England            NaN         True

# %%
cars_df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object', name='country code')

# %%
import numpy as np 
import pandas as pd 
cars_df = pd.read_csv(r'D:\Upgrad\Dataset\cars.csv', header=None) 
cars_df.columns = ["country code", "region","country","cars_per_caps","drive_right"] 
cars_df
# Out:
#   country code region        country  cars_per_caps  drive_right
# 0         USCA     US  United States          809.0        False
# 1        ASPAC    AUS      Australia          731.0         True
# 2        ASPAC    JAP          Japan          588.0         True
# 3        ASPAC     IN          India           18.0         True
# 4        ASPAC     RU         Russia          200.0        False
# 5        LATAM    MOR        Morocco           70.0        False
# 6          AFR     EG          Egypt           45.0        False
# 7          EUR    ENG        England            NaN         True

# %%
cars_df.set_index(["region", "country code"], inplace=True)
cars_df
# Out:
#                            country  cars_per_caps  drive_right
# region country code
# US     USCA          United States          809.0        False
# AUS    ASPAC             Australia          731.0         True
# JAP    ASPAC                 Japan          588.0         True
# IN     ASPAC                 India           18.0         True
# RU     ASPAC                Russia          200.0        False
# MOR    LATAM               Morocco           70.0        False
# EG     AFR                   Egypt           45.0        False
# ENG    EUR                 England            NaN         True

# %%
cars_df.head()
# Out:
#                            country  cars_per_caps  drive_right
# region country code
# US     USCA          United States          809.0        False
# AUS    ASPAC             Australia          731.0         True
# JAP    ASPAC                 Japan          588.0         True
# IN     ASPAC                 India           18.0         True
# RU     ASPAC                Russia          200.0        False

# %%
cars_df.tail()
# Out:
#                      country  cars_per_caps  drive_right
# region country code
# IN     ASPAC           India           18.0         True
# RU     ASPAC          Russia          200.0        False
# MOR    LATAM         Morocco           70.0        False
# EG     AFR             Egypt           45.0        False
# ENG    EUR           England            NaN         True

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8 entries, ('US', 'USCA') to ('ENG', 'EUR')
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        8 non-null      object
#  1   cars_per_caps  7 non-null      float64
#  2   drive_right    8 non-null      bool
# dtypes: bool(1), float64(1), object(1)
# memory usage: 844.0+ bytes

# %%
cars_df.shape
# Out:
# (8, 3)

# %%
print(cars_df.to_string())
# Out:
#                            country  cars_per_caps  drive_right
# region country code
# US     USCA          United States          809.0        False
# AUS    ASPAC             Australia          731.0         True
# JAP    ASPAC                 Japan          588.0         True
# IN     ASPAC                 India           18.0         True
# RU     ASPAC                Russia          200.0        False
# MOR    LATAM               Morocco           70.0        False
# EG     AFR                   Egypt           45.0        False
# ENG    EUR                 England            NaN         True

# %%
cars_df.to_csv(r"D:\Upgrad\Dataset\cars123.csv")

# %% [markdown]
# # Sales Dataset

# %%
sales = pd.read_csv(r"D:\Upgrad\Dataset\Online Sales Data.csv")
sales
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  02-01-2024  Home Appliances
# 2             10003  03-01-2024         Clothing
# 3             10004  04-01-2024            Books
# 4             10005  05-01-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro         2.0      999.99
# 1                                   Dyson V11 Vacuum         1.0      499.99
# 2                                   Levi's 501 Jeans         3.0       69.99
# ...

# %%
print(sales.to_string())
# Out:
#      Transaction ID        Date Product Category                                                Product Name  Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0             10001  01-01-2024      Electronics                                               iPhone 14 Pro         2.0      999.99        1999.98  North America    Credit Card
# 1             10002  02-01-2024  Home Appliances                                            Dyson V11 Vacuum         1.0      499.99         499.99         Europe         PayPal
# 2             10003  03-01-2024         Clothing                                            Levi's 501 Jeans         3.0       69.99         209.97           Asia     Debit Card
# 3             10004  04-01-2024            Books                                           The Da Vinci Code         4.0       15.99          63.96  North America    Credit Card
# ...

# %%
sales.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0         2.0      999.99        1999.98  North America    Credit Card
# 1         1.0      499.99         499.99         Europe         PayPal
# 2         3.0       69.99         209.97           Asia     Debit Card
# 3         4.0       15.99          63.96  North America    Credit Card
# 4         1.0       89.99          89.99         Europe         PayPal

# %%
sales.tail()
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker         1.0      159.99
# 236                        Nike Air Force 1 Sneakers         3.0       90.00
# 237           The Handmaid's Tale by Margaret Atwood         3.0       10.99
# 238             Sunday Riley Luna Sleeping Night Oil         1.0       55.00
# 239                       Yeti Rambler 20 oz Tumbler         2.0       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# ...
